# %%
import pandas as pd
df = pd.read_csv('.\dataset\weather.csv', index_col = 0, encoding = 'CP949')
df.fillna(0, inplace = True)

# %%
print(df.loc['2012-02-11'])
# Out:
# 평균기온(°C)     -0.7
# 최대 풍속(m/s)    0.0
# 평균 풍속(m/s)    0.0
# Name: 2012-02-11, dtype: float64

# %%
df = pd.DataFrame({'name': ['Adam', 'Babe', 'Cary', 'Dan', 'Emma'],
'age': [20, 30, 40, 50, 60],
'height': [173.5, 180.7, 188.1, 167.7, 160.0]})
print(df)
# Out:
#    name  age  height
# 0  Adam   20   173.5
# 1  Babe   30   180.7
# 2  Cary   40   188.1
# 3   Dan   50   167.7
# 4  Emma   60   160.0

# %%
df1 = df.melt()
print(df1)

# %%
df1 = pd.DataFrame({'A': ['a10', 'a11', 'a12'],
'B': ['b10', 'b11', 'b12'],
'C': ['c10', 'c11', 'c12']}, index = [0, 1, 2])
df2 = pd.DataFrame({'B': ['b10', 'b11', 'b12'],
'C': ['c10', 'c11', 'c12'],
'D': ['d10', 'd11', 'd12']}, index = [2, 3, 4])
print(df1)
print(df2)
# Out:
#      A    B    C
# 0  a10  b10  c10
# 1  a11  b11  c11
# 2  a12  b12  c12
#      B    C    D
# 2  b10  c10  d10
# 3  b11  c11  d11
# 4  b12  c12  d12

# %%
df1 = pd.DataFrame({'A': ['a10', 'a11', 'a12'],
'B': ['b10', 'b11', 'b12'],
'C': ['c10', 'c11', 'c12']}, index = [0, 1, 2])
df2 = pd.DataFrame({'B': ['b20', 'b21', 'b22'],
'C': ['c20', 'c21', 'c22'],
'D': ['d20', 'd21', 'd22']}, index = [2, 3, 4])
df3 = df1.merge(df2, how = 'outer', left_index = True, right_index = True)
print(df3)
# Out:
#      A  B_x  C_x  B_y  C_y    D
# 0  a10  b10  c10  NaN  NaN  NaN
# 1  a11  b11  c11  NaN  NaN  NaN
# 2  a12  b12  c12  b20  c20  d20
# 3  NaN  NaN  NaN  b21  c21  d21
# 4  NaN  NaN  NaN  b22  c22  d22

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('./img/north-by-northwest-cary-grant-1959-everett.jpg')
print(img)
plt.imshow(img)
plt.show()
# Out:
# [[[211 252 248]
#   [211 252 248]
#   [211 252 248]
#   ...
#   [211 252 248]
#   [211 252 248]
#   [211 252 248]]
#
#  [[211 252 248]
#   [211 252 248]
#   [211 252 248]
#   ...
#   [211 252 248]
#   [211 252 248]
#   [211 252 248]]
#
#  [[211 252 248]
#   [211 252 248]
#   [211 252 248]
#   ...
#   [211 252 248]
#   [211 252 248]
#   [211 252 248]]
#
#  ...
#
#  [[154 156 177]
#   [147 149 170]
#   [159 161 182]
#   ...
#   [229 229 231]
#   [242 242 244]
#   [221 221 223]]
#
#  [[160 162 183]
#   [152 154 175]
#   [162 164 185]
#   ...
#   [235 235 237]
#   [219 219 221]
#   [228 228 230]]
#
#  [[152 154 175]
#   [144 146 167]
#   [157 159 180]
#   ...
#   [228 228 230]
#   [203 203 205]
#   [243 243 245]]]
