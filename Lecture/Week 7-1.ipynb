# %%
import csv

f = open('.\dataset\weather.csv')
data = csv.reader(f)
for row in data:
    print(row)
f.close()
# Out:
# ['일시', '평균기온(°C)', '최대 풍속(m/s)', '평균 풍속(m/s)']
# ['2010-08-01', '28.7', '8.3', '3.4']
# ['2010-08-02', '25.2', '8.7', '3.8']
# ['2010-08-03', '22.1', '6.3', '2.9']
# ['2010-08-04', '25.3', '6.6', '4.2']
# ['2010-08-05', '27.2', '9.1', '5.6']
# ['2010-08-06', '26.8', '9.8', '8']
# ['2010-08-07', '27.5', '9.1', '5']
# ['2010-08-08', '26.6', '5.9', '4']
# ['2010-08-09', '26.9', '5.1', '3.1']
# ['2010-08-10', '25.6', '10.2', '5.5']
# ['2010-08-11', '24.6', '9.4', '4.8']
# ['2010-08-12', '23.7', '8.7', '2.6']
# ['2010-08-13', '24.3', '10.9', '4.6']
# ['2010-08-14', '25', '10.8', '4.4']
# ['2010-08-15', '24.5', '16.9', '10.3']
# ['2010-08-16', '26.2', '9.8', '3.2']
# ['2010-08-17', '23.9', '4.2', '1.6']
# ['2010-08-18', '23.4', '4.2', '2.1']
# ['2010-08-19', '24.3', '4', '1.9']
# ['2010-08-20', '25.4', '5', '3.2']
# ['2010-08-21', '27.8', '7.6', '4.2']
# ['2010-08-22', '28.3', '5.9', '2.5']
# ['2010-08-23', '28.9', '9.3', '6.2']
# ['2010-08-24', '27.5', '8.3', '3']
# ...

# %%
import pandas as pd
name_series = pd.Series(['Cary Grant', 'George Clooney', 'Tom Cruise', 'Cameron Diaz', 'Liz Taylor'])
age_series = pd.Series([127, 61, 60, 50, 90])
gender_series = pd.Series(['M', 'M', 'M', 'F' ,'F'])
score_series = pd.Series([9.7, 9.3, 8.8, 8.5, 9.6])
df = pd.DataFrame({'name': name_series, 'age': age_series, 'gender': gender_series, 'score': score_series})

print(df)
# Out:
#              name  age gender  score
# 0      Cary Grant  127      M    9.7
# 1  George Clooney   61      M    9.3
# 2      Tom Cruise   60      M    8.8
# 3    Cameron Diaz   50      F    8.5
# 4      Liz Taylor   90      F    9.6

# %%
df = pd.read_csv('.\dataset\countries.csv')
print(df)
# Out:
#   Unnamed: 0 country      area     capital  population
# 0         KR   Korea     98480       Seoul    51780579
# 1         US     USA   9629091  Washington   331002825
# 2         JP   Japan    377835       Tokyo   125960000
# 3         CN   China   9596960     Beijing  1439323688
# 4         RU  Russia  17100000      Moscow   146748600

# %%
import pandas as pd
import matplotlib.pyplot as plt
df2 = pd.read_csv('.\dataset\countries.csv', index_col = 0)
# df2['population'].plot(kind = 'bar', color = ('b', 'g', 'r', 'm', 'darkorange'))
df2['population'].plot(kind = 'pie')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('.\dataset\weather.csv', index_col = 0, encoding = 'CP949')
df3['평균 풍속(m/s)'].plot(kind = 'hist', bins = 33)
plt.show()
